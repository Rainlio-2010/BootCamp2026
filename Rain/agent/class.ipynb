# %%
from openai import OpenAI
client = OpenAI(
    base_url="http://localhost:1234/v1",
    api_key="lm-studio" 
)

model="qwen3.5-9b-mlx"

response = client.responses.create(
    model= model,
    input="Write a one-sentence bedtime story about a unicorn."
)

print(response.output_text)
# Out:
# As the moonlight glowed softly on its spiraled horn, the unicorn closed its eyes and drifted into a dream of endless meadows where the stars whispered lullabies.<|im_end|>
